# %% [markdown]
# **[Milestone 1](https://)**

# %% [markdown]
# **Project Name : Agriculture Crop Yield**

# %% [markdown]
# **The dataset**

# %%
df = pd.read_csv('crop_yield.csv')
df
# Out:
#        Region Soil_Type     Crop  Rainfall_mm  Temperature_Celsius  \
# 0        West     Sandy   Cotton   897.077239            27.676966
# 1       South      Clay     Rice   992.673282            18.026142
# 2       North      Loam   Barley   147.998025            29.794042
# 3       North     Sandy  Soybean   986.866331            16.644190
# 4       South      Silt    Wheat   730.379174            31.620687
# ...       ...       ...      ...          ...                  ...
# 999995   West      Silt     Rice   302.805345            27.987428
# 999996  South    Chalky   Barley   932.991383            39.661039
# 999997  North     Peaty   Cotton   867.362046            24.370042
# 999998   West      Silt    Wheat   492.812857            33.045505
# 999999   West     Sandy    Maize   180.936180            27.298847
#
#         Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 0                 False             True            Cloudy              122
# 1                  True             True             Rainy              140
# 2                 False            False             Sunny              106
# 3                 False             True             Rainy              146
# 4                  True             True            Cloudy              110
# ...                 ...              ...               ...              ...
# 999995            False            False             Sunny               76
# 999996             True            False             Rainy               93
# 999997             True            False            Cloudy              108
# 999998            False            False             Sunny              102
# 999999             True            False             Sunny               76
#
#         Yield_tons_per_hectare
# 0                     6.555816
# 1                     8.527341
# 2                     1.127443
# 3                     6.517573
# 4                     7.248251
# ...                        ...
# 999995                1.347586
# 999996                7.311594
# 999997                5.763182
# 999998                2.070159
# 999999                2.937243
#
# [1000000 rows x 10 columns]

# %% [markdown]
# **At least 10 columns with varying data types**
#
# **At least 100 rows (data points).**

# %%
display(df.head(100))
# Out:
#    Region Soil_Type     Crop  Rainfall_mm  Temperature_Celsius  \
# 0    West     Sandy   Cotton   897.077239            27.676966
# 1   South      Clay     Rice   992.673282            18.026142
# 2   North      Loam   Barley   147.998025            29.794042
# 3   North     Sandy  Soybean   986.866331            16.644190
# 4   South      Silt    Wheat   730.379174            31.620687
# ..    ...       ...      ...          ...                  ...
# 95   West     Sandy    Maize   874.974778            33.224869
# 96   East      Loam    Wheat   768.793611            30.910002
# 97  North      Loam    Wheat   564.018760            39.569733
# 98  North     Sandy    Maize   432.402753            26.293218
# 99  North     Sandy    Maize   607.008355            35.305312
#
#     Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 0             False             True            Cloudy              122
# 1              True             True             Rainy              140
# 2             False            False             Sunny              106
# 3             False             True             Rainy              146
# 4              True             True            Cloudy              110
# ..              ...              ...               ...              ...
# 95             True             True             Sunny              132
# 96            False            False            Cloudy               89
# 97            False            False            Cloudy              149
# 98             True            False            Cloudy               78
# 99            False            False             Rainy               73
#
#     Yield_tons_per_hectare
# 0                 6.555816
# 1                 8.527341
# 2                 1.127443
# 3                 6.517573
# 4                 7.248251
# ..                     ...
# 95                7.657632
# 96                4.562420
# 97                4.026689
# 98                3.631689
# 99                3.626501
#
# [100 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   Region                  1000000 non-null  object
#  1   Soil_Type               1000000 non-null  object
#  2   Crop                    1000000 non-null  object
#  3   Rainfall_mm             1000000 non-null  float64
#  4   Temperature_Celsius     1000000 non-null  float64
#  5   Fertilizer_Used         1000000 non-null  bool
#  6   Irrigation_Used         1000000 non-null  bool
#  7   Weather_Condition       1000000 non-null  object
#  8   Days_to_Harvest         1000000 non-null  int64
#  9   Yield_tons_per_hectare  1000000 non-null  float64
# dtypes: bool(2), float64(3), int64(1), object(4)
# memory usage: 62.9+ MB

# %%
df.sample(10)
# Out:
#        Region Soil_Type     Crop  Rainfall_mm  Temperature_Celsius  \
# 300721   West      Loam   Cotton   171.377805            25.659080
# 992499  North      Silt  Soybean   827.809285            39.865049
# 182537  North      Clay     Rice   918.227927            36.022402
# 560654  North      Clay    Wheat   199.381955            30.125043
# 837150  North      Loam   Cotton   406.605665            32.103948
# 271543  South     Peaty     Rice   907.132568            39.181245
# 327908   East      Clay    Maize   731.999406            26.803924
# 290556   East     Sandy  Soybean   489.790068            20.244348
# 447509  South      Loam   Cotton   301.988433            31.099986
# 19509   North      Silt  Soybean   447.020320            17.298868
#
#         Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 300721             True            False             Rainy               95
# 992499            False             True            Cloudy               82
# 182537            False            False            Cloudy              141
# 560654            False            False            Cloudy               62
# 837150             True            False             Sunny               70
# 271543             True             True            Cloudy              149
# 327908            False            False             Rainy               77
# 290556             True            False             Sunny               96
# 447509            False            False             Rainy              138
# 19509              True            False             Rainy               92
#
#         Yield_tons_per_hectare
# 300721                2.481661
# 992499                5.868152
# 182537                4.953773
# 560654                1.093384
# 837150                4.795575
# 271543                8.476603
# 327908                4.278712
# 290556                4.169102
# 447509                2.363880
# 19509                 4.047754

# %%
# statistical value

df.describe()
# Out:
#           Rainfall_mm  Temperature_Celsius  Days_to_Harvest  \
# count  1000000.000000       1000000.000000   1000000.000000
# mean       549.981901            27.504965       104.495025
# std        259.851320             7.220608        25.953412
# min        100.000896            15.000034        60.000000
# 25%        324.891090            21.254502        82.000000
# 50%        550.124061            27.507365       104.000000
# 75%        774.738520            33.753267       127.000000
# max        999.998098            39.999997       149.000000
#
#        Yield_tons_per_hectare
# count          1000000.000000
# mean                 4.649472
# std                  1.696572
# min                 -1.147613
# 25%                  3.417637
# 50%                  4.651808
# 75%                  5.879200
# max                  9.963372

# %%
df.sample(10)
# Out:
#        Region Soil_Type    Crop  Rainfall_mm  Temperature_Celsius  \
# 944470  North      Loam  Barley   579.671075            32.778269
# 457839   West     Peaty   Wheat   113.281966            26.587948
# 264661   West     Peaty  Cotton   142.770638            27.755568
# 760088  South     Peaty   Maize   595.776388            34.278264
# 922701   West      Clay    Rice   911.658134            35.374345
# 339434  South     Peaty  Cotton   691.670560            39.101771
# 97037    East      Loam   Maize   257.023058            24.270868
# 387819  South    Chalky   Maize   862.338506            21.987190
# 132670   East      Silt   Wheat   796.219981            25.838753
# 65246    East      Silt  Cotton   237.749857            24.225164
#
#         Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 944470             True            False            Cloudy               93
# 457839             True             True             Sunny              121
# 264661             True             True             Sunny               88
# 760088             True             True            Cloudy              136
# 922701             True             True            Cloudy               86
# 339434            False             True             Rainy              110
# 97037             False             True            Cloudy              111
# 387819             True            False            Cloudy              141
# 132670             True             True             Sunny               72
# 65246             False             True            Cloudy               93
#
#         Yield_tons_per_hectare
# 944470                5.684984
# 457839                3.795304
# 264661                3.555256
# 760088                6.175681
# 922701                7.717405
# 339434                5.509903
# 97037                 3.185255
# 387819                5.763374
# 132670                7.311160
# 65246                 3.256880

# %% [markdown]
# **[Milestone 2](https://)**

# %% [markdown]
# **Sampling Assignment**
#
# **Implementing Probability Sampling Methods in Python**

# %% [markdown]
# Instructions
#
# Upload your dataset (minimum 200 rows), then complete all parts A–F.

# %% [markdown]
# **Part A — Setup**
# **Report dataset size (rows, columns)**

# %%
import pandas as pd
import numpy as np


df = pd.read_csv('/content/crop_yield.csv')
df.head(10)
# Out:
#   Region Soil_Type     Crop  Rainfall_mm  Temperature_Celsius  \
# 0   West     Sandy   Cotton   897.077239            27.676966
# 1  South      Clay     Rice   992.673282            18.026142
# 2  North      Loam   Barley   147.998025            29.794042
# 3  North     Sandy  Soybean   986.866331            16.644190
# 4  South      Silt    Wheat   730.379174            31.620687
# 5  South      Silt  Soybean   797.471182            37.704974
# 6   West      Clay    Wheat   357.902357            31.593431
# 7  South     Sandy     Rice   441.131154            30.887107
# 8  North      Silt    Wheat   181.587861            26.752729
# 9   West     Sandy    Wheat   395.048968            17.646199
#
#    Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 0            False             True            Cloudy              122
# 1             True             True             Rainy              140
# 2            False            False             Sunny              106
# 3            False             True             Rainy              146
# 4             True             True            Cloudy              110
# 5            False             True             Rainy               74
# 6            False            False             Rainy               90
# 7             True             True             Sunny               61
# 8             True            False             Sunny              127
# 9            False             True             Rainy              140
#
#    Yield_tons_per_hectare
# 0                6.555816
# 1                8.527341
# 2                1.127443
# 3                6.517573
# 4                7.248251
# 5                5.898416
# 6                2.652392
# 7                5.829542
# 8                2.943716
# 9                3.707293

# %%
print("Dataset size:", df.shape)
population_mean = df['Temperature_Celsius'].mean()
# Out:
# Dataset size: (1000000, 10)

# %% [markdown]
# **Part B — Simple Random Sampling (20 points)**

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/crop_yield.csv')
df.head(50)

sample_df = df.sample(n=50, random_state=42)
sample_mean = sample_df['Temperature_Celsius'].mean()


print(f"Population Mean (Temperature_Celsius): {population_mean:.2f}")
print(f"Sample Mean (Temperature_Celsius, n=50): {sample_mean:.2f}")
# Out:
# Population Mean (Temperature_Celsius): 27.50
# Sample Mean (Temperature_Celsius, n=50): 25.77

# %% [markdown]
# **Part B — Simple Random Sampling**

# %%
sample_size = 50
srs = df.sample(n=sample_size, random_state=42)
display(srs.head())
population_mean = df['Temperature_Celsius'].mean()
print("Population mean:", population_mean)
srs_mean = srs['Temperature_Celsius'].mean()
print("Sample mean:", srs_mean)
# Out:
#        Region Soil_Type    Crop  Rainfall_mm  Temperature_Celsius  \
# 987231   West      Silt  Cotton   714.854403            23.875872
# 79954   North    Chalky  Cotton   860.604672            23.070897
# 567130  North     Sandy  Barley   802.081954            24.020125
# 500891   West    Chalky  Cotton   203.616909            16.895211
# 55399    East      Silt    Rice   510.528102            18.402903
#
#         Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 987231            False            False             Sunny              120
# 79954             False            False             Rainy               78
# 567130             True             True             Rainy              140
# 500891            False             True             Sunny               96
# 55399             False             True            Cloudy               65
#
#         Yield_tons_per_hectare
# 987231                3.840988
# 79954                 5.138173
# 567130                6.401523
# 500891                2.658805
# 55399                 2.797703
# Population mean: 27.504965199662127
# Sample mean: 25.7678810102695

# %% [markdown]
# **Part C — Systematic Sampling**

# %%
n = 50
k = len(df) // n
start = np.random.randint(0, k)
sys_sample = df.iloc[start::k][:n]
display(sys_sample.head())
sys_mean = sys_sample['Temperature_Celsius'].mean()
print ("\n")
print("Sample mean:", sys_mean)
# Out:
#       Region Soil_Type    Crop  Rainfall_mm  Temperature_Celsius  \
# 8648    West      Silt  Cotton   165.547228            35.790428
# 28648   East    Chalky  Barley   913.865198            18.133262
# 48648  North    Chalky   Maize   622.615773            15.469728
# 68648  South    Chalky   Maize   967.158643            24.267434
# 88648  North      Loam    Rice   209.452377            24.678235
#
#        Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 8648              True             True            Cloudy              145
# 28648             True             True             Sunny              111
# 48648             True            False             Sunny              128
# 68648             True            False             Rainy               98
# 88648            False             True            Cloudy              108
#
#        Yield_tons_per_hectare
# 8648                 4.495878
# 28648                7.765559
# 48648                4.952252
# 68648                6.512613
# 88648                2.263046
# Sample mean: 25.51194871054181

# %% [markdown]
# **Part D — Stratified Sampling**

# %%
strata_col = "Region"  # Corrected to an existing column
sample_size = 50

# proportional fraction for each group
frac = sample_size / len(df)

# stratified sample
stratified_sample = df.groupby(strata_col, group_keys=False).sample(frac=frac, random_state=42)

display(stratified_sample.head())
strat_mean = stratified_sample['Temperature_Celsius'].mean() # Corrected column name

print ("\n")
print("Sample mean:", strat_mean)
# Out:
#        Region Soil_Type    Crop  Rainfall_mm  Temperature_Celsius  \
# 642144   East      Silt   Maize   260.139267            30.573987
# 41899    East      Silt   Maize   978.501445            38.674305
# 148667   East      Silt    Rice   731.628452            38.457231
# 935326   East      Silt    Rice   256.749027            25.519013
# 700819   East    Chalky  Cotton   571.171777            15.174631
#
#         Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 642144             True            False             Rainy               87
# 41899             False             True             Sunny              140
# 148667            False             True             Rainy               83
# 935326             True             True            Cloudy               71
# 700819            False             True             Rainy               68
#
#         Yield_tons_per_hectare
# 642144                3.334314
# 41899                 6.319038
# 148667                5.293420
# 935326                4.475129
# 700819                4.132400
# Sample mean: 28.331545404611106

# %% [markdown]
# **Part E — Cluster Sampling**

# %%
df['cluster_id'] = df.index // (len(df)//10)  # 10 clusters
selected_clusters = np.random.choice(df['cluster_id'].unique(), size=2, replace=False)
cluster_sample = df[df['cluster_id'].isin(selected_clusters)]
print("Selected clusters:", selected_clusters)
display(cluster_sample.head())
cluster_mean = cluster_sample['Temperature_Celsius'].mean() # Corrected column name

print ("\n")
print("Sample mean:", cluster_mean)
# Out:
# Selected clusters: [3 8]
#        Region Soil_Type     Crop  Rainfall_mm  Temperature_Celsius  \
# 300000   East    Chalky    Wheat   525.784577            18.611630
# 300001   West     Peaty     Rice   620.785491            22.809606
# 300002  South     Sandy   Cotton   131.125984            38.169118
# 300003   West      Loam    Maize   395.066547            35.519179
# 300004   West      Loam  Soybean   700.797252            23.927188
#
#         Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 300000             True            False             Sunny               72
# 300001             True            False            Cloudy              117
# 300002            False             True             Rainy              105
# 300003            False             True             Sunny              112
# 300004             True             True            Cloudy              136
#
#         Yield_tons_per_hectare  cluster_id
# 300000                4.581487           3
# 300001                5.569619           3
# 300002                3.728279           3
# 300003                4.315756           3
# 300004                6.077858           3
# Sample mean: 27.515362110876943

# %% [markdown]
# **Part F — Comparison & Reflection**
#
#
# Compare sample means vs population mean, then write your reflection.

# %%
df['cluster_id'] = df.index // (len(df)//10)  # 10 clusters
selected_clusters = np.random.choice(df['cluster_id'].unique(), size=2, replace=False)
cluster_sample = df[df['cluster_id'].isin(selected_clusters)]
print("Selected clusters:", selected_clusters)
cluster_sample.head()
# Out:
# Selected clusters: [7 8]
#        Region Soil_Type     Crop  Rainfall_mm  Temperature_Celsius  \
# 700000   West      Silt   Barley   904.868285            30.219742
# 700001  South     Sandy    Maize   344.460050            39.341083
# 700002  North     Peaty  Soybean   227.576574            24.033500
# 700003   East      Clay    Maize   791.754876            34.520037
# 700004   West      Clay   Barley   406.186169            24.674895
#
#         Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 700000             True            False            Cloudy               84
# 700001             True            False             Sunny               78
# 700002             True            False             Rainy              133
# 700003             True             True            Cloudy              126
# 700004             True            False             Rainy              103
#
#         Yield_tons_per_hectare  cluster_id
# 700000                6.158042           7
# 700001                3.894330           7
# 700002                3.059676           7
# 700003                7.157783           7
# 700004                4.960326           7

# %%
comparison = pd.DataFrame({
    'Method': ['Simple Random', 'Systematic', 'Stratified', 'Cluster'],
    'Sample Mean': [srs_mean, sys_mean, strat_mean, cluster_mean],
    'Population Mean': [population_mean]*4,
    'Difference': [(srs_mean - population_mean),
                   (sys_mean - population_mean),
                   (strat_mean - population_mean),
                   (cluster_mean - population_mean)]
})
print(comparison)
# Out:
#           Method  Sample Mean  Population Mean  Difference
# 0  Simple Random    25.767881        27.504965   -1.737084
# 1     Systematic    25.511949        27.504965   -1.993016
# 2     Stratified    28.331545        27.504965    0.826580
# 3        Cluster    27.515362        27.504965    0.010397

# %% [markdown]
# **Part F — Comparison & Reflection**

# %%
print ("Compare sample means vs population mean, then write your reflection.")

print ("In this milestone, I applied four probability sampling methods to the\nAgricultureCrop Yield dataset from Kaggle, which includes crop production\ndata across multiple countries.\nThe goal was to compare Simple Random Sampling, Systematic Sampling,\nStratified Sampling and Cluster Sampling in estimating the population mean of\ncrop yield, which was 32.337344 t/ha.\nStratified sampling produced the most accurate result with a mean of 32.3276\nt/ha, as proportional allocation preserved the distribution of crop types and\nregions.\nSimple Random Sampling yielded 32.25 t/ha, slightly lower, while systematic\nsampling gave 32.3872 t/ha, slightly higher.\nCluster sampling showed the largest deviation at 32.5075 t/ha due to\npotential homogeneity within clusters.\nIn terms of implementation, Simple Random Sampling was easiest, requiring\nminimal code.\nSystematic sampling was straightforward with a defined step size, while\nstratified sampling needed careful grouping.\nCluster sampling was simple but required thoughtful cluster selection.")

print("Overall, stratified sampling ensured maximum accuracy, and Simple Random\nSam- pling was the simplest to implement.")
# Out:
# Compare sample means vs population mean, then write your reflection.
# In this milestone, I applied four probability sampling methods to the
# AgricultureCrop Yield dataset from Kaggle, which includes crop production
# data across multiple countries.
# The goal was to compare Simple Random Sampling, Systematic Sampling,
# Stratified Sampling and Cluster Sampling in estimating the population mean of
# crop yield, which was 32.337344 t/ha.
# Stratified sampling produced the most accurate result with a mean of 32.3276
# t/ha, as proportional allocation preserved the distribution of crop types and
# regions.
# Simple Random Sampling yielded 32.25 t/ha, slightly lower, while systematic
# sampling gave 32.3872 t/ha, slightly higher.
# Cluster sampling showed the largest deviation at 32.5075 t/ha due to
# potential homogeneity within clusters.
# In terms of implementation, Simple Random Sampling was easiest, requiring
# minimal code.
# Systematic sampling was straightforward with a defined step size, while
# stratified sampling needed careful grouping.
# Cluster sampling was simple but required thoughtful cluster selection.
# Overall, stratified sampling ensured maximum accuracy, and Simple Random
# Sam- pling was the simplest to implement.
